# %% [markdown]
# <a href="https://colab.research.google.com/github/Loveline-Ezenwafor/Analysis-by-Loveline-Ezenwafor/blob/Analysis%2FPython-Programming/Insights_through_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import os

import google.generativeai as genai

# %% [markdown]
# ## Model setup

# %%
# configure API Key
genai.configure(api_key="AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8")

# %%
# Create the model
# See https://ai.google.dev/api/python/google/generativeai/GenerativeModel
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

# %%
model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

# %% [markdown]
# ## Start a chat session

# %%
chat_session = model.start_chat(
  history=[]
)
response = chat_session.send_message("write a python code to sort an array in the most efficient way as possible.")

print(response.text)
# Out:
# ```python
# import random
#
# def sort_array(array):
#   """Sorts an array using the most efficient algorithm (Timsort).
#
#   Args:
#     array: The array to be sorted.
#
#   Returns:
#     The sorted array.
#   """
#   return sorted(array)
#
# # Generate a random array of integers
# array = [random.randint(0, 100) for _ in range(1000)]
#
# # Sort the array
# sorted_array = sort_array(array)
#
# # Print the sorted array
# print(sorted_array)
# ```
#
# **Explanation:**
#
# 1. **`sorted(array)`:** This line uses the built-in `sorted()` function in Python. This function uses the **Timsort** algorithm, which is a hybrid sorting algorithm that is highly efficient for real-world data. Timsort leverages the advantages of both merge sort and insertion sort to provide fast and stable sorting.
#
# 2. **Efficiency:** Timsort has an average time complexity of **O(n log n)**, making it highly efficient for large datasets. It also has a space complexity of **O(n)**, but in practice, it often uses much less space.
#
# 3. **Built-in Advantages:** Using the `sorted()` function is the most efficient way to sort an array in Python because:
#     * It's optimized for speed and memory efficiency.
#     * It's written in C, making it significantly faster than a Python implementation.
#     * It's part of the standard library, so you don't need to install any additional packages.
#
# **Note:** While other sorting algorithms like merge sort and quicksort can be implemented in Python, they are not as efficient as the built-in `sorted()` function which utilizes Timsort.

# %% [markdown]
# # Module 4: Insights Through AI

# %% [markdown]
# Welcome to Module 4! In this module, you'll explore how to leverage Gemini AI to extract meaningful insights from your data. This module aims to introduce you to the practical applications of advanced AI models, focusing on extracting and interpreting data insights.

# %% [markdown]
# ### Learning Objectives:
# - Understand the basics of Gemini AI and its applications in data analysis.
# - Learn how large language models (LLMs) like Gemini AI work.
# - Utilize Gemini AI to analyze and extract insights from your dataset.
# - Interpret the results provided by Gemini AI and draw meaningful conclusions.
#
# Let's get started!

# %% [markdown]
# ## Section 1: Introduction to Gemini AI
#
# ### **What is Gemini AI?**
#
# [Gemini AI](https://blog.google/technology/ai/google-gemini-ai/) is an advanced language model designed to understand and generate human-like text. It can analyze large volumes of text data, summarize information, and provide insightful responses based on the input it receives.
#
# ### Key Features and Capabilities:
# - **Text Analysis:** Gemini AI can process and analyze text data to identify key themes, sentiments, and insights.
# - **Summarization:** It can summarize long documents, making it easier to extract important information quickly.
# - **Conversational Abilities:** Gemini AI can engage in human-like conversations, providing relevant and coherent responses.

# %% [markdown]
# ## Section 2: Setting Up Gemini AI
#
# Now to work with Gemini directly from Python, we need to use its API.
#
# An API, or Application Programming Interface, is like a messenger that takes requests and tells a system what you want to do. Then it returns the system's response back to you. It's a way for different software programs to talk to each other.
#
# ### Simple Example:
# Think of an API as a waiter in a restaurant. You (the user) tell the waiter (API) what you want from the menu (the system). The waiter takes your order to the kitchen (the system), and then brings your food (response) back to you.
#
# ### Step-by-Step Guide to Creating and Setting Up Your Gemini AI API Key:
# 1. Search for "Gemini AI API" on Google.
# 2. Select the official Gemini AI API page on ai.google.dev.
# 3. Navigate to the "Get API key in Google AI Studio" section.
# 4. Create a new project or select an existing project to generate an API key.
# 5. Copy the API key and ensure not to share it publicly for security reasons.
#
# Once you have your API key, let's start coding our system.

# %% [markdown]
# ## Simple Chatbot Setup using Python and Gemini API

# %%
import google.generativeai as genai

# Function to set up a simple chatbot
def simple_chatbot(api_key, message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    response = chat_session.send_message(message)
    return response.text

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8"

message = "Write a short funny story"
chatbot_response = simple_chatbot(api_key, message)
print(chatbot_response)
# Out:
# Bartholomew "Bart" Bumblesnort, a man whose name perfectly described his life, was convinced he had a magical touch. It wasn't the kind that turned pumpkins into carriages, but rather, a talent for turning ordinary objects into hilarious disasters.
#
# One sunny afternoon, Bart decided to impress his neighbour, Mrs. Peabody, with his culinary prowess. He decided to bake her a birthday cake. With a flourish, he grabbed a whisk, whipped up the batter, and plopped it into the oven. Ten minutes later, a loud BANG echoed through the house.  The oven door flew open, spewing a cloud of smoke and what looked suspiciously like a burnt, molten pancake.
#
# "Oh, dear," Bart sighed, picking up the pan with a pair of oven mitts. "Seems like I might need a new oven. Or maybe a new recipe."
#
# Later that evening, Bart decided to paint the fence. He dipped his brush into the bucket and started with a flourish. One swipe later, a large, bright green bird appeared on the fence. "Quite a colorful bird," Bart chuckled, trying to wipe off the paint with a damp cloth. Unfortunately, the cloth stuck to the fence, leaving a large, gooey stain.
#
# "Perhaps painting isn't my forte," he mumbled to himself.
#
# Finally, exhausted from his artistic endeavours, Bart sat down to read the newspaper.  He flipped it open, and in an instant, a picture of a politician's face morphed into a grinning monkey. He screamed, flinging the newspaper across the room.  "I give up! I'm cursed!"
#
# Mrs. Peabody, who had witnessed the entire spectacle from her window, chuckled. She came over with a plate of warm cookies.  "Don't worry, Bart," she said with a smile. "You're not cursed. You're just… uniquely talented."
#
# Bart, looking at the monkey-faced politician in the newspaper, realized that Mrs. Peabody was right. He might be a walking disaster, but at least he brought laughter to the neighborhood.

# %% [markdown]
# ## Section 3: Integrating Gemini AI with Your Dataset
#
# Now that you've set up the API and created a simple chatbot, let's move on to using Gemini AI with a dataset. We'll be working with a pandas DataFrame to send data to the API for analysis.

# %%
import pandas as pd
import google.generativeai as genai

# Load your dataset
df = pd.read_csv('your_dataset.csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
# Select a subset of reviews

reviews_column_name = 'Description'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "Analyze the following reviews and summarize the key insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Key Insights from Apple Watch SE 2023 Reviews:
#
# **Pros:**
#
# * **High Quality & Features:**  Reviewers consistently praise the build quality, features, and performance of the Apple Watch SE 2023.
# * **Crisp AMOLED Display:**  The display is well-received, though the lack of Always-On Display is a drawback for some.
# * **Smooth WatchOS:** The user interface is lauded for its smooth operation and intuitive design.
# * **Excellent Call Quality:**  Users are impressed with the clarity and ease of making calls directly from the watch.
# * **Accurate Tracking:**  Reviewers confirm the Apple Watch's reputation for accurate tracking of fitness metrics like sleep, steps, and heart rate.
# * **Good Value for Money:**  Many reviewers find the SE 2023 to be a great value proposition considering its price point and features.
#
# **Cons:**
#
# * **Battery Life:**  A common complaint is the battery life, which many find to be only a single day's worth, especially with heavy usage or workout modes.
# * **Lack of Advanced Features:**  The SE 2023 lacks some features found on the more expensive Apple Watch 8, such as ECG, blood oxygen monitoring, and Always-On Display.
# * **Limited Water Resistance:**  While water-resistant, the watch does not accept input when submerged.
# * **Small Screen Size:**  Some users find the screen size (especially the 40mm version) to be too small.
#
# **Other Observations:**
#
# * **Price Comparison:**  Some reviewers recommend opting for the Apple Watch 8 if the price difference is minimal, as it offers more features.
# * **Cellular Connectivity:**  The cellular version is highly praised for its convenience during workouts or when leaving the phone behind.
# * **Personal Preference:**  The choice of Apple Watch SE 2023 is often driven by individual needs and priorities. For example, those seeking basic features and a smooth experience find it very appealing.
#
# **Overall:**
#
# The Apple Watch SE 2023 is a well-regarded smartwatch offering a solid balance of features, performance, and price. It's a great option for first-time Apple Watch users and those seeking a basic yet reliable smartwatch experience. However, its shortcomings in battery life and lack of advanced features may deter users with specific needs.

# %% [markdown]
# ## Section 4: Gathering Insights
#
# Now that you've set up Gemini AI and integrated it with your dataset, it's time to dive into gathering insights. This section will guide you through developing effective prompts, extracting key information, and interpreting the results to gain meaningful insights.
#
# ### Developing Effective Prompts
#
# Creating the right prompts is crucial for getting useful responses from Gemini AI. Here, we'll explore how to craft prompts that help extract specific information, such as pain points and positive aspects from customer reviews.

# %% [markdown]
# **Extracting Pain Points:** To identify common issues or complaints in customer reviews, you can create a prompt that specifically asks Gemini AI to summarize the negative aspects.

# %%
# Select a subset of reviews

reviews_column_name = 'Description'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "Analyze the negative reviews and summarize the key pain points:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Apple Watch SE 2023: Key Pain Points from Negative Reviews
#
# While many reviewers praise the Apple Watch SE 2023 for its features, quality, and user experience, there are some consistent negative points:
#
# **1. Battery Life:** This is the most common complaint. Many users find the battery life to be inadequate, particularly when using workout modes or making lengthy calls. Several reviewers mention needing to charge the watch twice daily if they exercise frequently.
#
# **2. Price Compared to Apple Watch 8:**  Some reviewers argue that the price difference between the SE and Watch 8 is negligible, making the Watch 8 a better value proposition, especially since it offers features like Always-On Display, ECG, and Blood Oxygen Monitoring.
#
# **3.  Limited Water Resistance:** Although the watch is advertised as water-resistant, users have pointed out that it does not accept inputs while submerged. This limitation can be frustrating for swimming or other water activities.
#
# **4. Small Screen:**  Some find the screen size, especially the 40mm version, to be too small for their preference.
#
# **5.  Lack of Features:**  The SE 2023 lacks features found in higher-end Apple Watches, like Always-On Display, ECG, and Blood Oxygen Monitoring. This might be a deal-breaker for users who prioritize these features.
#
# **6.  Charging Time:**  One reviewer mentioned that the watch takes 2 hours to charge to 100%, which might be considered long compared to other smartwatches.
#
# **7.  Build Quality:** One user reported a broken display, although this could be an isolated case.
#
# **Overall, the Apple Watch SE 2023 is a good value option for those looking for a basic Apple Watch experience with decent performance and quality. However, users should be aware of the limitations in battery life, water resistance, and feature set compared to the more expensive Apple Watch 8.**

# %% [markdown]
# ## Section 5: Hands-On Practice
#
# Now that you know how to use the Gemini API to gather insights, feel free to experiment as much as possible. Remember: The goal is to understand the voice of the customer through their feedback. By developing effective prompts and interpreting the AI's responses, you can uncover valuable insights that drive better decision-making.
