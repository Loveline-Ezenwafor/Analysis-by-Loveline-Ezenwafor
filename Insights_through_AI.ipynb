# %% [markdown]
# <a href="https://colab.research.google.com/github/Loveline-Ezenwafor/Analysis-by-Loveline-Ezenwafor/blob/Analysis%2FPython-Programming/Insights_through_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import os

import google.generativeai as genai

# %% [markdown]
# ## Model setup

# %%
# configure API Key
genai.configure(api_key="AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8")

# %%
# Create the model
# See https://ai.google.dev/api/python/google/generativeai/GenerativeModel
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

# %%
model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

# %% [markdown]
# ## Start a chat session

# %%
chat_session = model.start_chat(
  history=[]
)

response = chat_session.send_message("Write a Python code to sort an array in the most efficient way possible using quicksort algorithm.")

print(response.text)

# %% [markdown]
# # Module 4: Insights Through AI

# %% [markdown]
# Welcome to Module 4! In this module, you'll explore how to leverage Gemini AI to extract meaningful insights from your data. This module aims to introduce you to the practical applications of advanced AI models, focusing on extracting and interpreting data insights.

# %% [markdown]
# ### Learning Objectives:
# - Understand the basics of Gemini AI and its applications in data analysis.
# - Learn how large language models (LLMs) like Gemini AI work.
# - Utilize Gemini AI to analyze and extract insights from your dataset.
# - Interpret the results provided by Gemini AI and draw meaningful conclusions.
#
# Let's get started!

# %% [markdown]
# ## Section 1: Introduction to Gemini AI
#
# ### **What is Gemini AI?**
#
# [Gemini AI](https://blog.google/technology/ai/google-gemini-ai/) is an advanced language model designed to understand and generate human-like text. It can analyze large volumes of text data, summarize information, and provide insightful responses based on the input it receives.
#
# ### Key Features and Capabilities:
# - **Text Analysis:** Gemini AI can process and analyze text data to identify key themes, sentiments, and insights.
# - **Summarization:** It can summarize long documents, making it easier to extract important information quickly.
# - **Conversational Abilities:** Gemini AI can engage in human-like conversations, providing relevant and coherent responses.

# %% [markdown]
# ## Section 2: Setting Up Gemini AI
#
# Now to work with Gemini directly from Python, we need to use its API.
#
# An API, or Application Programming Interface, is like a messenger that takes requests and tells a system what you want to do. Then it returns the system's response back to you. It's a way for different software programs to talk to each other.
#
# ### Simple Example:
# Think of an API as a waiter in a restaurant. You (the user) tell the waiter (API) what you want from the menu (the system). The waiter takes your order to the kitchen (the system), and then brings your food (response) back to you.
#
# ### Step-by-Step Guide to Creating and Setting Up Your Gemini AI API Key:
# 1. Search for "Gemini AI API" on Google.
# 2. Select the official Gemini AI API page on ai.google.dev.
# 3. Navigate to the "Get API key in Google AI Studio" section.
# 4. Create a new project or select an existing project to generate an API key.
# 5. Copy the API key and ensure not to share it publicly for security reasons.
#
# Once you have your API key, let's start coding our system.

# %% [markdown]
# ## Simple Chatbot Setup using Python and Gemini API

# %%
import google.generativeai as genai

# Function to set up a simple chatbot
def simple_chatbot(api_key, message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    response = chat_session.send_message(message)
    return response.text

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8"

message = "Write a short funny story"
chatbot_response = simple_chatbot(api_key, message)
print(chatbot_response)
# Out:
# Bartholomew the hamster was not a fan of change. He liked his routine: wake up, eat sunflower seeds, run in his wheel, take a nap, eat some more sunflower seeds, and repeat. So when his human, a well-meaning but slightly absent-minded teenager named Emily, replaced his boring, beige wheel with a fancy, neon-green one, Bartholomew was not amused.
#
# "This is an outrage!" Bartholomew squeaked, his tiny whiskers trembling in indignation. "This monstrosity is far too bright. I can't even sleep with this monstrosity staring at me!"
#
# He refused to even touch the new wheel, preferring to stubbornly walk around in circles on the floor, much to Emily's amusement. "Come on, Bartholomew," she said, chuckling, "it's just a wheel. It's not like it's going to bite you."
#
# Bartholomew huffed and puffed, but eventually, hunger got the better of him. He peeked at the bright green wheel, its colors practically screaming at him. He scurried closer, and to his surprise, he found himself strangely drawn to the bright colors. He tentatively took a sniff, and then, to his own shock, he took a tentative step onto the wheel.
#
# The moment his tiny paws touched the wheel, it started to spin, sending him soaring through the air with a whoosh. It was exhilarating! Bartholomew, who had initially been terrified, found himself squealing with delight. He ran faster and faster, his tiny body a blur of grey fur against the bright green background.
#
# He finally stopped, breathless and giggling, realizing he'd had a lot of fun. He looked at the bright green wheel with newfound appreciation. It wasn't so bad after all. In fact, it was kind of... cool.
#
# From that day forward, Bartholomew became the most enthusiastic hamster in the neighborhood. He'd proudly spin his neon-green wheel, leaving other hamsters envious of his flamboyant ride. And Emily? She couldn't help but smile at the sight of her grumpy little hamster, now a champion of the colorful wheel.

# %% [markdown]
# ## Section 3: Integrating Gemini AI with Your Dataset
#
# Now that you've set up the API and created a simple chatbot, let's move on to using Gemini AI with a dataset. We'll be working with a pandas DataFrame to send data to the API for analysis.

# %%
import pandas as pd
import google.generativeai as genai

# Load your dataset
df = pd.read_csv('your_dataset.csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCv4LukY53WXhkVZykj8tihVehTqBtq1p8"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
# Select a subset of reviews

reviews_column_name = 'Description'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "Analyze the following reviews and summarize the key insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Apple Watch SE 2023 Reviews: Key Insights
#
# The Apple Watch SE 2023 receives mixed reviews, with some praising its features, quality, and user experience, while others highlight its shortcomings, particularly regarding battery life. Here's a summary of the key insights:
#
# **Positives:**
#
# * **Excellent Features and Quality:** Many users highlight the Watch SE's impressive features for its price range, including a crisp AMOLED display, smooth Watch OS, accurate tracking, and reliable performance.
# * **Amazing Call Quality:** Users consistently praise the clarity and ease of communication through the watch.
# * **User-Friendly Interface:** The Watch OS is commended for its intuitive design, making it easy to navigate even for first-time Apple Watch users.
# * **Impressive Accuracy:** The Apple Watch SE 2023 is acknowledged for its accurate tracking of various metrics like sleep, steps, and heart rate.
# * **Great Value for Money:**  Several reviewers express their satisfaction with the price-to-performance ratio of the Watch SE 2023, especially when compared to other brands.
# * **Solid Build Quality and Design:** The watch is lauded for its durable and stylish design.
#
# **Negatives:**
#
# * **Limited Features:** The absence of features like Always-on Display, Blood Oxygen Monitor, and ECG is a drawback for some users who might prefer a more feature-rich smartwatch.
# * **Battery Life Concerns:** The most prominent concern is the battery life, which is reported to be only a day's worth, especially when using demanding features like workout modes or cellular calls.
# * **Small Screen Size:** Some users find the screen size too small, potentially affecting their overall experience.
# * **Price Comparison with Apple Watch 8:**  The similar price point of the Apple Watch 8 leads some users to recommend opting for the latter model, especially if features like AOD and ECG are important.
#
# **Overall:**
#
# The Apple Watch SE 2023 presents a good value proposition for users seeking a reliable, stylish, and user-friendly smartwatch with core fitness and communication features. However, its battery life limitations and lack of advanced health monitoring features might discourage users who prioritize these aspects. Ultimately, the choice depends on individual needs and preferences, and careful consideration of these pros and cons is necessary.

# %% [markdown]
# ## Section 4: Gathering Insights
#
# Now that you've set up Gemini AI and integrated it with your dataset, it's time to dive into gathering insights. This section will guide you through developing effective prompts, extracting key information, and interpreting the results to gain meaningful insights.
#
# ### Developing Effective Prompts
#
# Creating the right prompts is crucial for getting useful responses from Gemini AI. Here, we'll explore how to craft prompts that help extract specific information, such as pain points and positive aspects from customer reviews.

# %% [markdown]
# **Extracting Pain Points:** To identify common issues or complaints in customer reviews, you can create a prompt that specifically asks Gemini AI to summarize the negative aspects.

# %%
# Select a subset of reviews

reviews_column_name = 'Description'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "Analyze the negative reviews and summarize the key pain points:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Key Pain Points of Apple Watch SE 2023:
#
# The reviews highlight several pain points regarding the Apple Watch SE 2023:
#
# **1. Battery Life:**
# * Several reviewers mention the battery life being "terrible" and needing to charge it daily, even with moderate use.
# * The battery drains quickly during workouts and long calls.
# * Some users find the battery life to be disappointing, especially compared to other smartwatches in the market.
#
# **2. Lack of Features for the Price:**
# * Some reviewers feel the features are too basic considering the price point.
# * They argue that Apple Watch 8 offers similar features and is priced competitively, making the SE less appealing.
# * Some users find the lack of AOD (Always On Display), ECG, and Blood Oxygen Monitor to be a significant drawback, especially since these features are available in competitor's devices at lower prices.
#
# **3. Screen Size:**
# * A few users find the screen size to be too small, especially for those with larger wrists.
#
# **4.  Water Resistance Limitations:**
# * Although the watch is water-resistant, it cannot accept input while submerged.
# * This limits its functionality for activities like swimming, where users may want to control their workout through the watch.
#
# **5.  Unexpectedly High Price:**
# * One user mentions receiving a conflicting price for the 44mm SE compared to the 40mm version, finding the pricing inconsistent and confusing.
#
# **Overall:**
#
# While the Apple Watch SE 2023 receives praise for its smooth UI, accurate tracking, and calling quality, its shortcomings in battery life, lack of premium features, and screen size are key areas of concern for potential buyers. Considering its price point, many users believe that Apple Watch 8 offers better value for the features it provides.

# %% [markdown]
# ## Section 5: Hands-On Practice
#
# Now that you know how to use the Gemini API to gather insights, feel free to experiment as much as possible. Remember: The goal is to understand the voice of the customer through their feedback. By developing effective prompts and interpreting the AI's responses, you can uncover valuable insights that drive better decision-making.

# %%
import nltk
from textblob import TextBlob
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Ensure that the NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load the dataset from CSV
df = pd.read_csv('your_dataset.csv')  # Adjust the path if necessary

# Extract the feedback from the 'Description' column
feedback_list = df['Description'].dropna().tolist()

# Step 1: Perform sentiment analysis on feedback
def analyze_sentiment(feedback):
    analysis = TextBlob(feedback)
    sentiment = analysis.sentiment.polarity  # Polarity ranges from -1 (negative) to 1 (positive)
    return sentiment

# Step 2: Extract common themes from feedback using keywords
def extract_keywords(feedback_list):
    stop_words = set(nltk.corpus.stopwords.words('english'))
    all_words = []

    for feedback in feedback_list:
        tokens = nltk.word_tokenize(feedback.lower())
        keywords = [word for word in tokens if word.isalnum() and word not in stop_words]
        all_words.extend(keywords)

    # Get the most common keywords
    most_common_words = Counter(all_words).most_common(10)
    return most_common_words

# Step 3: Summarize overall feedback
def summarize_feedback(feedback_list):
    combined_feedback = " ".join(feedback_list)
    blob = TextBlob(combined_feedback)
    summary = blob.sentences[:5]  # Grab the first 5 sentences for a quick summary
    return " ".join(str(sentence) for sentence in summary)

# Step 4: Generate insights based on feedback analysis
def generate_insights(feedback_list):
    # Sentiment analysis
    sentiments = [analyze_sentiment(feedback) for feedback in feedback_list]
    average_sentiment = sum(sentiments) / len(sentiments)

    # Extract keywords
    keywords = extract_keywords(feedback_list)

    # Summarize feedback
    summary = summarize_feedback(feedback_list)

    # Print insights
    print("=== Customer Feedback Insights ===")
    print(f"Average Sentiment Score: {average_sentiment:.2f}")
    print("Top Keywords:")
    for word, freq in keywords:
        print(f"{word}: {freq} occurrences")
    print("\nSummary of Feedback:")
    print(summary)

    # Visualize results
    plot_sentiment_distribution(sentiments)
    plot_keyword_frequencies(keywords)
    plot_word_cloud(feedback_list)

# Visualization functions
def plot_sentiment_distribution(sentiments):
    plt.figure(figsize=(10, 6))
    sns.histplot(sentiments, kde=True, bins=20, color='skyblue')
    plt.title('Distribution of Sentiment Scores')
    plt.xlabel('Sentiment Score')
    plt.ylabel('Frequency')
    plt.show()

def plot_keyword_frequencies(keywords):
    words, frequencies = zip(*keywords)

    plt.figure(figsize=(12, 8))
    sns.barplot(x=list(frequencies), y=list(words), palette='viridis')
    plt.title('Top Keywords in Feedback')
    plt.xlabel('Frequency')
    plt.ylabel('Keywords')
    plt.show()

def plot_word_cloud(feedback_list):
    combined_feedback = " ".join(feedback_list)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(combined_feedback)

    plt.figure(figsize=(12, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Feedback')
    plt.show()

# Generate insights and visualize results
generate_insights(feedback_list)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# === Customer Feedback Insights ===
# Average Sentiment Score: 0.35
# Top Keywords:
# watch: 3536 occurrences
# read: 2770 occurrences
# one: 1220 occurrences
# battery: 1212 occurrences
# good: 1020 occurrences
# apple: 928 occurrences
# rate: 894 occurrences
# heart: 864 occurrences
# life: 854 occurrences
# use: 852 occurrences
#
# Summary of Feedback:
# Very good in terms of features and amazing quality. Reliable in terms of performance and battery capacity. Read more This is the first time I am using an Apple Watch. After a lot of reviews and comparisons, I finally decided to go for the Apple Watch SE 2023 for:1) The crisp AMOLED display (Always on Display not available) - If you guys need the AOD, please skip this watch.2) Basic Features - As this is my first apple watch, I thought I need to get used to the UI and the gestures so I personally decided to go for the watch that has latest OS and processor with minimal and basic functions. (Blood Oxygen and ECG not available - if that is your priority, please skip this watch)3) Smooth Watch OS - This is by far the best UI I have ever used in a smart watch.
# <ipython-input-39-7ffc15bcd9c4>:85: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(words), palette='viridis')
