# %% [markdown]
# <a href="https://colab.research.google.com/github/Loveline-Ezenwafor/Analysis-by-Loveline-Ezenwafor/blob/Analysis%2FPython-Programming/NLTK_and_TextBlob_Tutorial_%26_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

# %% [markdown]
# ## Brief Intro about NLP (Natural Language Processing)
#
# Natural Language processing is a subfield in Artificial Intelligence and computer science which majorly focuses on creating and building application that can understand human language. And Python is preferred for this as well due to its vast availability of libraries. NLP involves in recognizing text and speech. Following are few of the practical examples of NLP.
# 1. Email Filters - This is one of the most basic application of NLP. Mails are catagorised using few words or phrases that signals that it is a spam.
# 2. Smart Assistants - Apple's siri and Amazon's Alexa recognizes our command through speech and act accordingly.
# 3. Search Results - Whenever we search any information in browser results of similar searches also will be listed. This will help the user to find what they want without refining their search text / phrase.
# 4. Predictive text - Auto correct, Autocomplete and predictive text features in our smartphones.
# 5. Language Transalation - Online translators
# 6. Digital Phone calls - Automated phone calls / reminders in case if we have any service due for our vehicle / if our mobile recharge plan is about to expire.
#
# So far, we have seen few real world examples of NLP, Now lets see a couples of libraries that contributes to achieve these apps /  features.
# 1. NLTK - Natural Language ToolKit
# 2. TextBlob
#
# ### Natural Language ToolKit
# NLTK stands for Natural Language Toolkit. It's a powerful set of tools and libraries that helps computers understand and work with human language, like English or any other language. NLTK is like a toolbox for programmers and researchers who want to build programs that can read, analyze, and generate human language. Altogether NLTK is a versatile and comprehensice toolkit that helps developers and researchers to work with human language in a more structured and intelligent way.
#
# #### What does NLTK do?
# 1. Text Processing - NLTK helps break down text into smaller parts, like sentences or words. This process is called Tokenization. If you take the previous sentence "This process is called tokenization", this will be split as ["This","process","is","called","tokenization"]
# 2. Language Analysis - NLTK can analyse the structure and meaning of sentences. It can tell you things like which words are nouns, verbs, adjectives etc. This is called part-of-speech tagging. For instance, in the sentence "The cat is sleeping", NLTK can tag "cat" as a noun and "sleeping" as a verb.
# 3. Sentiment Analysis - NLTK can also understand emotions and sentiments in text. For example, it can tell whether a snetiment expresses a positive, negative or neutral sentiment. This is useful for tasks like analysing customer reviews and social media post.
# 4. Machine Learning - NLTK includes tools for building and training machine learning models for language-related tasks. This allows developers to create custom solutions for specific language processing problems. However we will not cover this in this notebook, since it is not for beginners. :)

# %% [markdown]
# ### Installation
#
# The below code installs both nltk and textblob libraries.

# %%
# !pip install nltk
# !pip install textblob
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.5)

# %% [markdown]
# After NLTK and Textblob libraries are installed we would need to import them in order to use it utilities. Lets first see NLTK.

# %% [markdown]
# #### 1. Text Processing / Tokenization

# %%
#import the main NLTK library and sub-library to avail its functionalities.
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# Punkt model is used for word tokenization. There are dedicated packages for each kind of tasks. For eg. there is something called "WordNet" with which we can find meaning of words, synonyms, antonyms and much more.

# %%
# Download NLTK data (if not already downloaded)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Sample text
text = "NLTK is a powerful library for natural language processing."

# Tokenize the text
tokens = word_tokenize(text)
print("Tokenized Text:", tokens)
# Out:
# Tokenized Text: ['NLTK', 'is', 'a', 'powerful', 'library', 'for', 'natural', 'language', 'processing', '.']

# %% [markdown]
# #### 2. Language Analysis

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text = "NLTK is a powerful library for natural language processing."
text = nltk.word_tokenize(text)
pos_tagged = nltk.pos_tag(text)
pos_tagged
# Out:
# [('NLTK', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('powerful', 'JJ'),
#  ('library', 'NN'),
#  ('for', 'IN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('.', '.')]

# %% [markdown]
# In the above given output, Nouns (NN, NNP), verbs (VBZ), Determiners (DT), Adjuctive (JJ), Preposition (IN)  are identified and tagged.

# %% [markdown]
# #### 3. Sentiment Analysis
#
# Sentiment Analysis can be done in three ways.
# 1. Lexican based Analysis - This is a straight-forward one, may not be accurate but will be apt for the beginners to get trained. This basically works based on the predefined set of rules, that identifies the positive or negative words present in the given phrase.
# 2. Machine Learning
# 3. Pre-trained transformer-based deep learning
#
# 2 & 3 requires more understanding about the machine learning concepts and its computationally expensive to implement. Now lets see a very basic example using lexican based analysis

# %%
nltk.download('vader_lexicon') # This needs to be downloaded for lexican based analysis.
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# Initialize the sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Sample text
text = input("Enter the phrase for analysis")

# Analyze sentiment
sentiment_scores = sid.polarity_scores(text)

# Print the sentiment scores
print("Sentiment Scores:", sentiment_scores)

# Determine sentiment based on the compound score
if sentiment_scores['compound'] >= 0.05:
    print("Positive Sentiment")
elif sentiment_scores['compound'] <= -0.05:
    print("Negative Sentiment")
else:
    print("Neutral Sentiment")
# Out:
# Enter the phrase for analysisI love you Loveline! You are beautiful
# Sentiment Scores: {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.8553}
# Positive Sentiment

# %% [markdown]
# ### Textblob
# Textblob is a beginner friendly library that helps computers understand and work with human language in a simple way. It's built on top of NLTK (Natural Language Toolkit) and provides an easier interface for common language processing tasks.
#
# #### What does Textblob do?
#
# 1. Text Processing.
# 2. Sentiment Analysis.
# 3. Part-of-Speech Tagging
# 4. Noun Phrase Extraction: TextBlob can extract meaningful phrases from text. For instance, in the sentence "The big brown dog", TextBlob can identify "big brown dog" as a noun phrase.
#
# Overall, TextBlob simplifies the process of working with text data by providing easy-to-use functions for tasks like sentiment analysis, part-of-speech tagging, noun phrase extraction, and more. It's a great tool for beginners and anyone looking for a user-friendly approach to natural language processing.
#
# <u>One of the primary questions is why we have both TextBlob and NLTK when TextBlob essentially performs the same tasks as NLTK and is built on top of it.</u>
#
# TextBlob stands out due to its simplified and user-friendly approach, making it ideal for developers seeking minimal customizations and straightforward configurations in NLP app development. On the other hand, NLTK offers a broader range of functionalities, extensive customization options, and detailed configuration settings for users requiring advanced control and flexibility.

# %% [markdown]
# #### 1. Text Processing

# %%
from textblob import TextBlob
text = user_input = input("Enter a phrase to tokenise")
textblob_obj = TextBlob(text)
print("Tokens:", textblob_obj.tokens)
# Out:
# Enter a phrase to tokenise'This', 'is', 'an', 'example', 'sentence', '.'
# Tokens: ["'This", "'", ',', "'is", "'", ',', "'an", "'", ',', "'example", "'", ',', "'sentence", "'", ',', "'", '.', "'"]

# %% [markdown]
# #### 2. Sentiment Analysis

# %%
user_input = input("Enter a phrase to evaluate")
textblob_obj = TextBlob(user_input)
polarity = textblob_obj.sentiment.polarity
subjectivity = textblob_obj.sentiment.subjectivity

# Interpret sentiment scores
if polarity > 0:
    sentiment_label = "Positive"
elif polarity < 0:
    sentiment_label = "Negative"
else:
    sentiment_label = "Neutral"

print("Sentiment Analysis:")
print(f"Polarity: {polarity} ({sentiment_label})")
print(f"Subjectivity: {subjectivity}")
# Out:
# Enter a phrase to evaluateI love this Externship!
# Sentiment Analysis:
# Polarity: 0.625 (Positive)
# Subjectivity: 0.6

# %% [markdown]
# ##### Polarity:
#
# The polarity score indicates the sentiment of the text, ranging from -1 (very negative) to 1 (very positive). Here's a breakdown of polarity values:
#
# Polarity close to 1: Indicates a positive sentiment. The closer it is to 1, the stronger the positive sentiment.
# Polarity close to -1: Indicates a negative sentiment. The closer it is to -1, the stronger the negative sentiment.
# Polarity around 0: Indicates a neutral sentiment. Polarity values close to 0 suggest that the text is neither positive nor negative.
#
# ##### Subjectivity:
# The subjectivity score measures the subjectivity of the text, ranging from 0 to 1.
#
# Subjectivity close to 0: Indicates that the text is more objective and factual.
# Subjectivity close to 1: Indicates that the text is more subjective and opinionated.

# %% [markdown]
# #### 3. Part-of-speech Tagging

# %%
text = user_input = input("Enter a phrase to do pos-tagging :")
textblob_obj = TextBlob(text)
print("POS tags:", textblob_obj.tags)
# Out:
# Enter a phrase to do pos-tagging :The quick brown fox jumps over the lazy dog.
# POS tags: [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN')]

# %% [markdown]
# #### 4. Noun Phrase Extraction

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
text = user_input = input("Enter a phrase to extract :")
textblob_obj = TextBlob(text)
print("Noun Phrases tags:", textblob_obj.noun_phrases)
# Out:
# Enter a phrase to extract :The quick brown fox jumps over the lazy dog.
# Noun Phrases tags: ['quick brown fox jumps', 'lazy dog']

# %% [markdown]
# ### Exercises

# %%
# Create a simple program to do tokenisation

# %%
# Create a simple program to find the sentiment with user in

# %% [markdown]
# ### Exploratory Data Analysis
#
# Let us see the exploratory data analysis on a sample customer review dataset. This dataset contains review information about four leading smart watch brands. Columns comprise of Product Name, Customer Name, Star Rating, Review Description, Date, Comments. The Review Data has been scraped from the e-commerce website, structured in a dataset way and then uploaded to csv file.
#
# We will see the following steps in the dataset.
#
# 1. Loading and displaying the dataset's structure.
# 2. Computing summary statistics like mean, median, min, max, etc.
# 3. Checking for missing values.
# 4. Visualizing the distribution of ratings using a count plot.
# 5. Creating a word cloud to visualize common words in the review text.
# 6. Analyzing frequency counts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1. Loading and displaying the dataset's structure.

# %%
review_dataset = pd.read_csv("smartwatch-reviews.csv")
review_dataset.head()
# Out:
#                                         Product Name         Name  Stars  \
# 0  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...  Karthikeyan    5.0
# 1  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...     Vishvesh    4.0
# 2  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...        Bindu    5.0
# 3  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...   Sandhyaram    2.0
# 4  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...       Suresh    1.0
#
#                                                Title  Date  \
# 0       5.0 out of 5 stars\nGood and reliable watch.   NaN
# 1  4.0 out of 5 stars\nThe Perfect Budget Apple W...   NaN
# 2                       5.0 out of 5 stars\nGood One   NaN
# 3                2.0 out of 5 stars\nBattery problem   NaN
# 4               1.0 out of 5 stars\nNot as per image   NaN
#
#                                          Description
# 0  Very good in terms of features and amazing qua...
# 1  This is the first time I am using an Apple Wat...
# 2        Simple look with basic features.\nRead more
# 3                        2h charging 100%\nRead more
# 4                    Screen is very small\nRead more

# %%
review_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750 entries, 0 to 2749
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  2750 non-null   object
#  1   Name          2750 non-null   object
#  2   Stars         1760 non-null   float64
#  3   Title         2750 non-null   object
#  4   Date          0 non-null      float64
#  5   Description   2750 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 129.0+ KB

# %%
review_dataset.shape
# Out:
# (2750, 6)

# %% [markdown]
# #### 2. Computing summary statistics like mean, median, min, max, etc.

# %%
review_dataset.describe()
# Out:
#              Stars  Date
# count  1760.000000   0.0
# mean      4.414773   NaN
# std       1.147263   NaN
# min       1.000000   NaN
# 25%       4.000000   NaN
# 50%       5.000000   NaN
# 75%       5.000000   NaN
# max       5.000000   NaN

# %% [markdown]
# #### 3. Checking for missing values.

# %%
review_dataset.isna().sum()
# Out:
# Product Name       0
# Name               0
# Stars            990
# Title              0
# Date            2750
# Description        0
# dtype: int64

# %% [markdown]
# Now we have a basic idea about the dataset. Let us do a little bit of data cleaning. Lets start with removing unnecessary columns.
#
# If we look at the Date Column, there is no valid entry in that column. So we can remove that column from the dataset.

# %%
review_dataset = review_dataset.drop(["Date"],axis=1)
review_dataset.head()
# Out:
#                                         Product Name         Name  Stars  \
# 0  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...  Karthikeyan    5.0
# 1  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...     Vishvesh    4.0
# 2  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...        Bindu    5.0
# 3  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...   Sandhyaram    2.0
# 4  Apple Watch SE (2nd Gen, 2023) [GPS 40mm] Smar...       Suresh    1.0
#
#                                                Title  \
# 0       5.0 out of 5 stars\nGood and reliable watch.
# 1  4.0 out of 5 stars\nThe Perfect Budget Apple W...
# 2                       5.0 out of 5 stars\nGood One
# 3                2.0 out of 5 stars\nBattery problem
# 4               1.0 out of 5 stars\nNot as per image
#
#                                          Description
# 0  Very good in terms of features and amazing qua...
# 1  This is the first time I am using an Apple Wat...
# 2        Simple look with basic features.\nRead more
# 3                        2h charging 100%\nRead more
# 4                    Screen is very small\nRead more

# %% [markdown]
# The next column that needs attention is "Stars". First we will calculate the % of NULL values

# %%
review_dataset["Stars"].isnull().sum()/len(review_dataset)*100
# Out:
# 36.0

# %% [markdown]
# Since 36% of data is NULL, we can either drop null values or imputate. But since this is an important column in our analysis, it would be a better choice to drop null values. If the percentage is very less, say 5-10% we can imputate the null values with suitable value(mean or median or mode).

# %%
cleaned_review_dataset = review_dataset.dropna()

# %%
cleaned_review_dataset.isna().sum()
# Out:
# Product Name    0
# Name            0
# Stars           0
# Title           0
# Description     0
# dtype: int64

# %% [markdown]
# The dataset is clean now and ready for visualization. Let us look at the various options to visualize data.

# %% [markdown]
# #### 4. Visualizing the distribution of ratings using a count plot.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Stars', data=cleaned_review_dataset)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Stars', y='Product Name', data=cleaned_review_dataset)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 5. Creating a word cloud to visualize common words in the review text.
#
# Now lets see an important feature Wordcloud.

# %% [markdown]
# A word cloud is a visualization technique that represents text data where <font color='BLUE'><b>the size of each word indicates its frequency or importance within the text</b></font>. In a word cloud, <font color='YELLOW'>more frequent words are displayed with larger font sizes, making them visually prominent</font>. Word clouds are commonly used to gain insights into the most significant terms or themes in a body of text.

# %% [markdown]
# The significance of word clouds in sentiment analysis lies in their ability to:
#
# 1. Visualize Key Terms.
# 2. Highlight Sentiment-related Terms.
# 3. Discover Trends.
# 4. Communicate Findings.
# 5. Preprocessing and Feature Selection.
#
# While word clouds can be valuable in exploring and visualizing textual data, they should be used in conjunction with other analytical techniques, such as sentiment analysis algorithms, to provide a comprehensive understanding of sentiment trends and patterns within the data. Additionally, word clouds are more qualitative than quantitative, so they are often used as an exploratory tool rather than a definitive analysis method.

# %% [markdown]
# There are several varieties or types of word clouds, each with its own characteristics and applications. Here are some common varieties of word clouds:
#
#
# <u><b>1. Standard Word Clouds:</b></u>
#
# Standard word clouds, also known as basic word clouds, display words from a text dataset based on their frequency. The size of each word in the cloud corresponds to its frequency in the text. These word clouds are simple and effective for visualizing the most common terms in a dataset.

# %%
# Word cloud of review text
from wordcloud import WordCloud

# %%
# Combine all review text into a single string
all_reviews = ' '.join(cleaned_review_dataset['Description'].dropna())

# %%
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_reviews)

# %%
# Display word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Description Text')
plt.show()

# %%
all_titles = ' '.join(cleaned_review_dataset['Title'].dropna())

# %%
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_titles)

# %%
# Display word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Title Text')
plt.show()

# %%
all_prod_names = ' '.join(cleaned_review_dataset['Product Name'].dropna())

# %%
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_prod_names)

# %%
# Display word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Product')
plt.show()

# %% [markdown]
# <u><b>2. Weighted Word Clouds:</b></u>
#
# Weighted word clouds assign weights or importance scores to words based on criteria other than frequency alone. For example, sentiment analysis scores, TF-IDF (Term Frequency-Inverse Document Frequency) values, or custom weights can be used to determine the size or prominence of words in the cloud. Weighted word clouds provide a more nuanced view of the text data by highlighting important terms based on specific criteria.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = list(cleaned_review_dataset['Product Name'])

tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(corpus)
tfidf_scores = dict(zip(tfidf.get_feature_names_out(), tfidf.idf_))

wordcloud = WordCloud(width=800, height=400, background_color='white',
                      colormap='viridis', max_words=10, prefer_horizontal=0.7)
wordcloud.generate_from_frequencies(tfidf_scores)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Let us see another meaningful example with a sample text of our choice.

# %%
corpus = ["Python is a versatile programming language.",
          "Data analysis is an important skill in Python.",
          "Machine learning algorithms are used for predictive modeling."]

tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(corpus)
tfidf_scores = dict(zip(tfidf.get_feature_names_out(), tfidf.idf_))

wordcloud = WordCloud(width=800, height=400, background_color='white',
                      colormap='viridis', max_words=10, prefer_horizontal=0.7)
wordcloud.generate_from_frequencies(tfidf_scores)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <u><b>3. Hierarchical Word Clouds:</b></u>
#
# Hierarchical word clouds organize words into hierarchical or nested structures based on their relationships or categories. For example, words can be grouped into categories such as topics, sentiments, or themes, and displayed in a hierarchical manner within the word cloud. This type of word cloud is useful for visualizing complex relationships and structures within text data.

# %%
text = cleaned_review_dataset.Description.iloc[0]

wordcloud = WordCloud(collocations=False).generate(text)

plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# given below a better custom example for hierarchical word cloud

# %%
text = "Python Datascience machine learning python programming algorithms"

wordcloud = WordCloud(collocations=False).generate(text)

plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <b><u>4. Interactive Word Clouds:</u></b>
#
# Interactive word clouds allow users to interact with the visualization by hovering over words to display additional information, clicking on words to drill down into related content, or adjusting parameters to customize the display (e.g., font size, color scheme). Interactive word clouds enhance user engagement and exploration of textual data.

# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

text = cleaned_review_dataset['Product Name'].iloc[0]


# Generate word cloud using the WordCloud library
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Convert word cloud to plotly format
wordcloud_plotly = go.Figure(go.Image(z=wordcloud.to_array()))

# Configure layout and display the plot
wordcloud_plotly.update_layout(title='WordCloud', xaxis=dict(visible=False), yaxis=dict(visible=False))
iplot(wordcloud_plotly)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c454575-63a8-4616-896d-48aa82db18b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c454575-63a8-4616-896d-48aa82db18b6")) {                    Plotly.newPlot(                        "8c454575-63a8-4616-896d-48aa82db18b6",                        [{"z":[[[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255],[255,255,255] ...

# %% [markdown]
# In this i have added only one product name in place of the text to be displayed. We can still add some more features to this.
#
# By adding event handlers like creating a function for on_click event or hover event, we can make this one even interactive one.

# %% [markdown]
# <b><u>5. 3D Word Clouds:</u></b>
#
# 3D word clouds add a three-dimensional aspect to the visualization, creating a more visually immersive experience. Words are displayed in a three-dimensional space, with options for rotation, zooming, and perspective changes. While 3D word clouds can be visually appealing, they are sometimes criticized for potentially sacrificing readability and clarity compared to 2D word clouds.

# %% [markdown]
# <b><u>6. Customized Word Clouds:</u></b>
#
# Customized word clouds allow users to customize various aspects of the visualization, such as font styles, color palettes, background images, shape arrangements, and word orientations. These customization options enable users to create visually appealing and tailored word clouds that suit their specific needs and preferences.

# %%
text = cleaned_review_dataset['Description'].iloc[100]

wordcloud = WordCloud(background_color='black', colormap='Paired', contour_color='steelblue',
                      contour_width=2).generate(text)

plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Each variety of word cloud has its strengths and can be chosen based on the goals, data characteristics, and audience preferences for visualization and analysis.

# %% [markdown]
# #### 6. Analyzing frequency counts
#
# Frequency count plays a crucial role in sentiment analysis by helping to identify the importance and prevalence of words or phrases within a text dataset. In sentiment analysis, frequency count refers to the number of times a particular word or phrase appears in the text, and it provides valuable insights into the sentiment expressed in the data.
#
# Here's an overview of the role of frequency count in sentiment analysis:
#
# 1. Identifying Key Terms.
# 2. Understanding Sentiment Intensity.
# 3. Detecting Sentiment Trends.
# 4. Feature Selection.
# 5. Comparative Analysis.
#
#
# Let us see a simple example on our review dataset.

# %%
from collections import Counter

# Sample review dataset
reviews = list(cleaned_review_dataset['Description'].iloc[0:100])

# Tokenize and preprocess the reviews (remove punctuation and convert to lowercase)
processed_reviews = [' '.join(word.lower() for word in review.split() if word.isalnum()) for review in reviews]

# Count the frequency of each word in the processed reviews
word_count = Counter()
for review in processed_reviews:
    word_count.update(review.split())

# Display the word frequency count
print("Word Frequency Count:")
for word, count in word_count.items():
    print(f"{word}: {count}")
# Out:
# Word Frequency Count:
# very: 26
# good: 62
# in: 70
# terms: 8
# of: 20
# features: 12
# and: 119
# amazing: 4
# reliable: 4
# performance: 4
# battery: 35
# read: 100
# more: 109
# this: 67
# is: 116
# the: 232
# first: 17
# time: 4
# i: 115
# am: 4
# using: 26
# an: 8
# apple: 33
# after: 4
# a: 133
# lot: 4
# reviews: 4
# finally: 22
# decided: 8
# to: 96
# go: 26
# for: 100
# watch: 137
# se: 29
# 2023: 8
# crisp: 4
# amoled: 4
# display: 17
# on: 58
# not: 57
# if: 43
# you: 98
# guys: 4
# need: 8
# please: 8
# skip: 8
# basic: 21
# as: 34
# my: 31
# thought: 4
# get: 8
# used: 8
# ui: 8
# gestures: 4
# so: 22
# personally: 4
# that: 29
# has: 22
# latest: 4
# os: 8
# processor: 4
# with: 26
# minimal: 4
# oxygen: 8
# ecg: 4
# available: 4
# your: 48
# smooth: 4
# by: 4
# far: 4
# best: 13
# have: 53
# ever: 4
# smart: 4
# everything: 4
# looks: 4
# works: 13
# feels: 4
# calling: 4
# call: 4
# quality: 17
# user: 8
# at: 16
# other: 8
# end: 4
# cannot: 4
# tell: 4
# difference: 4
# whether: 4
# through: 8
# or: 4
# accuracy: 4
# heard: 4
# many: 13
# reviewers: 4
# saying: 4
# measuring: 8
# stick: 4
# all: 17
# tracking: 4
# heart: 4
# it: 143
# indeed: 4
# measurements: 4
# are: 35
# almost: 4
# accurate: 4
# when: 49
# compared: 8
# been: 13
# past: 13
# 2: 4
# months: 4
# never: 4
# really: 13
# found: 8
# any: 17
# noticeable: 4
# definitely: 8
# will: 22
# excellent: 4
# product: 22
# course: 4
# samsung: 4
# xiaomi: 4
# offers: 8
# better: 13
# such: 4
# blood: 4
# etc: 4
# lesser: 4
# price: 12
# but: 26
# considering: 4
# would: 13
# suggest: 4
# purchased: 13
# 25k: 4
# which: 17
# surprising: 4
# 44mm: 4
# range: 4
# was: 26
# confusing: 4
# 40mm: 13
# around: 4
# did: 4
# see: 4
# notable: 4
# got: 13
# low: 4
# tag: 4
# also: 4
# makes: 4
# me: 4
# adore: 4
# purchase: 4
# simple: 4
# look: 4
# 2h: 4
# charging: 4
# screen: 4
# small: 4
# terrible: 4
# think: 4
# improve: 4
# its: 22
# prices: 4
# 8: 12
# similar: 4
# can: 13
# till: 4
# stock: 4
# lastsso: 4
# buy: 8
# instead: 4
# regularly: 9
# year: 9
# simply: 9
# looking: 9
# ticks: 9
# right: 9
# cellular: 27
# those: 9
# times: 9
# reluctant: 9
# carry: 9
# phone: 9
# during: 9
# workout: 54
# tested: 9
# having: 9
# airpods: 9
# help: 9
# days: 9
# water: 36
# although: 9
# accept: 18
# input: 9
# soon: 9
# dries: 9
# enough: 9
# take: 9
# calls: 18
# listen: 9
# gets: 18
# drained: 9
# fast: 9
# mode: 18
# long: 9
# heated: 9
# up: 9
# becomes: 9
# cools: 9
# down: 9
# make: 9
# resistant: 9
# turn: 9
# jump: 9
# into: 9
# cant: 9
# do: 27
# once: 9
# charge: 36
# then: 9
# twice: 9
# budget: 9
# friendly: 9
# premium: 9
# worth: 18
# inr: 9
# space: 9
# grey: 9
# aluminium: 9
# case: 9
# black: 9
# sport: 9
# band: 9
# 3: 9
# october: 9
# 2021: 9
# packing: 9
# im: 9
# excited: 9
# unboxing: 9
# swichon: 9
# there: 9
# upset: 9
# nice: 9
# experience: 9
# updated: 9
# media: 18
# could: 18
# be: 27
# broken: 9
# money: 9
# know: 9
# great: 9
# build: 9
# comes: 9
# cute: 9
# order: 9
# version: 9
# fits: 9
# well: 9
# tiny: 9
# strap: 9
# leave: 9
# mark: 9
# before: 9
# mine: 9
# drain: 9
# only: 18
# concern: 9
# lasts: 9
# beast: 9

# %% [markdown]
# In this we have taken the description of the first 100 records, and the word count shows the most used words in the description. Out of 100 records, there are 62 occurences of the word "good", which shows that the first 100 record have more positive reviews.
